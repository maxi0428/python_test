# %%
import numpy as np

# %%
x_data1 =[[73., 80., 75.],
[93., 88., 93.],
[89., 91., 80.],
[96., 98., 100.],
[73., 66., 70.]]
t_data1 =[[152.], [185.], [180.], [196.], [142.]]

# %%
x_data=np.array(x_data1)
t_data=np.array(t_data1)
print(x_data)
print(t_data)
# Out:
# [[ 73.  80.  75.]
#  [ 93.  88.  93.]
#  [ 89.  91.  80.]
#  [ 96.  98. 100.]
#  [ 73.  66.  70.]]
# [[152.]
#  [185.]
#  [180.]
#  [196.]
#  [142.]]

# %%
w=np.random.rand(3,1)
b=np.random.rand(1)
print(w,b)
# Out:
# [[0.95858127]
#  [0.53846162]
#  [0.19292905]] [0.32439189]

# %%
def loss_func(x,t):
    y=np.dot(x,w)+b # y=xw+b
    return (np.sum((t-y)**2))/len(x)

# %%
def mul_numerical_derivative(f,x):
    delta_x=1e-4
    grad=np.zeros_like(x) # 미분 결과값 저장 배열

    it=np.nditer(x, flags=['multi_index'], op_flags=['readwrite'])
    while not it.finished:
        idx=it.multi_index

        tmp_val=x[idx]
        x[idx]=float(tmp_val)+delta_x
        fx1=f(x)
        x[idx]=tmp_val-delta_x
        fx2=f(x)
        grad[idx]=(fx1-fx2)/(2*delta_x)
        x[idx]=tmp_val
        it.iternext()
    return grad

# %%
def predict(x):
    y=np.dot(x,w)+b
    return y

# %%
learning_rate=1e-6

f=lambda x:loss_func(x_data, t_data)
print("Initial error value=",loss_func(x_data,t_data), 'w=',w,'b=',b)

for step in range(100000):
    w-=learning_rate*mul_numerical_derivative(f,w)
    b-=learning_rate*mul_numerical_derivative(f,b)
    if step%400==0:
        print("step=", step, "error value=", loss_func(x_data, t_data), 'w=',w,'b=',b)
# Out:
# Initial error value= 0.48790139838215546 w= [[1.08825311]
#  [0.65646874]
#  [0.27360037]] b= [0.32533378]
# step= 0 error value= 0.4878856767159167 w= [[1.08825541]
#  [0.65646954]
#  [0.27359724]] b= [0.32533374]
# step= 400 error value= 0.48165927870096514 w= [[1.08917284]
#  [0.65678261]
#  [0.27235199]] b= [0.32531812]
# step= 800 error value= 0.475555256208691 w= [[1.09008443]
#  [0.65708811]
#  [0.27112031]] b= [0.32530237]
# step= 1200 error value= 0.46957088817317255 w= [[1.09099024]
#  [0.65738615]
#  [0.26990204]] b= [0.32528648]
# step= 1600 error value= 0.4637035210274287 w= [[1.09189027]
#  [0.65767689]
#  [0.268697  ]] b= [0.32527047]
# step= 2000 error value= 0.45795056689168706 w= [[1.09278456]
#  [0.65796044]
#  [0.26750504]] b= [0.32525432]
# step= 2400 error value= 0.4523095018126064 w= [[1.09367314]
#  [0.65823694]
#  [0.266326  ]] b= [0.32523805]
# step= 2800 error value= 0.4467778640520267 w= [[1.09455604]
#  [0.65850651]
#  [0.26515972]] b= [0.32522165]
# step= 3200 error value= 0.44135325242405027 w= [[1.09543328]
#  [0.65876927]
#  [0.26400604]] b= [0.32520513]
# step= 3600 error value= 0.43603332467858114 w= [[1.0963049 ]
#  [0.65902536]
#  [0.26286481]] b= [0.32518848]
# step= 4000 error value= 0.43081579593054065 w= [[1.09717093]
#  [0.65927488]
#  [0.26173589]] b= [0.32517171]
# step= 4400 error value= 0.4256984371330663 w= [[1.09803139]
#  [0.65951796]
#  [0.26061911]] b= [0.32515481]
# step= 4800 error value= 0.4206790735933839 w= [[1.09888631]
#  [0.65975472]
#  [0.25951434]] b= [0.3251378]
# step= 5200 error value= 0.4157555835305267 w= [[1.09973573]
#  [0.65998526]
#  [0.25842143]] b= [0.32512066]
# step= 5600 error value= 0.4109258966731856 w= [[1.10057966]
#  [0.66020971]
#  [0.25734024]] b= [0.3251034]
# step= 6000 error value= 0.4061879928968774 w= [[1.10141814]
#  [0.66042817]
#  [0.25627062]] b= [0.32508603]
# step= 6400 error value= 0.4015399008992738 w= [[1.1022512 ]
#  [0.66064075]
#  [0.25521243]] b= [0.32506854]
# step= 6800 error value= 0.3969796969122486 w= [[1.10307887]
#  [0.66084756]
#  [0.25416554]] b= [0.32505093]
# step= 7200 error value= 0.3925055034501468 w= [[1.10390117]
#  [0.66104871]
#  [0.25312982]] b= [0.32503321]
# step= 7600 error value= 0.3881154880927761 w= [[1.10471814]
#  [0.66124429]
#  [0.25210512]] b= [0.32501537]
# step= 8000 error value= 0.38380786230235125 w= [[1.1055298 ]
#  [0.66143441]
#  [0.25109132]] b= [0.32499742]
# step= 8400 error value= 0.3795808802731292 w= [[1.10633618]
#  [0.66161918]
#  [0.25008828]] b= [0.32497935]
# step= 8800 error value= 0.37543283781337156 w= [[1.10713731]
#  [0.66179869]
#  [0.24909588]] b= [0.32496118]
# step= 9200 error value= 0.37136207125806864 w= [[1.10793322]
#  [0.66197303]
#  [0.24811399]] b= [0.32494289]
# step= 9600 error value= 0.367366956411855 w= [[1.10872393]
#  [0.6621423 ]
#  [0.24714248]] b= [0.32492449]
# step= 10000 error value= 0.3634459075213334 w= [[1.10950948]
#  [0.66230661]
#  [0.24618123]] b= [0.32490599]
# step= 10400 error value= 0.35959737627566 w= [[1.11028989]
#  [0.66246603]
#  [0.24523012]] b= [0.32488737]
# step= 10800 error value= 0.35581985083496326 w= [[1.1110652 ]
#  [0.66262066]
#  [0.24428902]] b= [0.32486865]
# step= 11200 error value= 0.352111854885363 w= [[1.11183542]
#  [0.6627706 ]
#  [0.24335782]] b= [0.32484983]
# step= 11600 error value= 0.3484719467203343 w= [[1.11260059]
#  [0.66291592]
#  [0.24243641]] b= [0.32483089]
# step= 12000 error value= 0.3448987183471885 w= [[1.11336073]
#  [0.66305672]
#  [0.24152466]] b= [0.32481186]
# step= 12400 error value= 0.34139079461810323 w= [[1.11411588]
#  [0.66319307]
#  [0.24062245]] b= [0.32479271]
# step= 12800 error value= 0.33794683238536455 w= [[1.11486606]
#  [0.66332507]
#  [0.23972969]] b= [0.32477347]
# step= 13200 error value= 0.3345655196794484 w= [[1.11561129]
#  [0.6634528 ]
#  [0.23884625]] b= [0.32475413]
# step= 13600 error value= 0.33124557490989015 w= [[1.11635162]
#  [0.66357633]
#  [0.23797203]] b= [0.32473468]
# step= 14000 error value= 0.3279857460879858 w= [[1.11708705]
#  [0.66369576]
#  [0.23710691]] b= [0.32471513]
# step= 14400 error value= 0.3247848100707457 w= [[1.11781763]
#  [0.66381114]
#  [0.2362508 ]] b= [0.32469548]
# step= 14800 error value= 0.32164157182557324 w= [[1.11854338]
#  [0.66392257]
#  [0.23540358]] b= [0.32467574]
# step= 15200 error value= 0.31855486371505626 w= [[1.11926433]
#  [0.66403011]
#  [0.23456515]] b= [0.3246559]
# step= 15600 error value= 0.3155235448011128 w= [[1.11998049]
#  [0.66413385]
#  [0.2337354 ]] b= [0.32463596]
# step= 16000 error value= 0.3125465001683669 w= [[1.12069191]
#  [0.66423386]
#  [0.23291424]] b= [0.32461592]
# step= 16400 error value= 0.3096226402656648 w= [[1.12139861]
#  [0.6643302 ]
#  [0.23210157]] b= [0.32459579]
# step= 16800 error value= 0.30675090026569674 w= [[1.12210062]
#  [0.66442295]
#  [0.23129728]] b= [0.32457556]
# step= 17200 error value= 0.3039302394418572 w= [[1.12279795]
#  [0.66451218]
#  [0.23050128]] b= [0.32455524]
# step= 17600 error value= 0.30115964056212857 w= [[1.12349065]
#  [0.66459796]
#  [0.22971347]] b= [0.32453483]
# step= 18000 error value= 0.2984381092993039 w= [[1.12417873]
#  [0.66468035]
#  [0.22893376]] b= [0.32451432]
# step= 18400 error value= 0.29576467365719883 w= [[1.12486222]
#  [0.66475942]
#  [0.22816205]] b= [0.32449372]
# step= 18800 error value= 0.29313838341231235 w= [[1.12554116]
#  [0.66483523]
#  [0.22739825]] b= [0.32447303]
# step= 19200 error value= 0.2905583095706443 w= [[1.12621556]
#  [0.66490786]
#  [0.22664226]] b= [0.32445225]
# step= 19600 error value= 0.2880235438390302 w= [[1.12688545]
#  [0.66497736]
#  [0.225894  ]] b= [0.32443139]
# step= 20000 error value= 0.2855331981108295 w= [[1.12755086]
#  [0.66504379]
#  [0.22515338]] b= [0.32441043]
# step= 20400 error value= 0.2830864039653137 w= [[1.12821181]
#  [0.66510722]
#  [0.22442031]] b= [0.32438938]
# step= 20800 error value= 0.28068231218057044 w= [[1.12886834]
#  [0.66516771]
#  [0.22369471]] b= [0.32436825]
# step= 21200 error value= 0.278320092259409 w= [[1.12952047]
#  [0.66522531]
#  [0.22297647]] b= [0.32434703]
# step= 21600 error value= 0.27599893196803255 w= [[1.13016822]
#  [0.66528008]
#  [0.22226553]] b= [0.32432573]
# step= 22000 error value= 0.273718036886915 w= [[1.13081161]
#  [0.66533208]
#  [0.2215618 ]] b= [0.32430434]
# step= 22400 error value= 0.27147662997383903 w= [[1.13145069]
#  [0.66538137]
#  [0.2208652 ]] b= [0.32428286]
# step= 22800 error value= 0.2692739511382801 w= [[1.13208546]
#  [0.66542799]
#  [0.22017563]] b= [0.32426131]
# step= 23200 error value= 0.26710925682751196 w= [[1.13271596]
#  [0.66547201]
#  [0.21949303]] b= [0.32423967]
# step= 23600 error value= 0.26498181962339873 w= [[1.13334221]
#  [0.66551348]
#  [0.21881731]] b= [0.32421794]
# step= 24000 error value= 0.2628909278500117 w= [[1.13396424]
#  [0.66555244]
#  [0.2181484 ]] b= [0.32419614]
# step= 24400 error value= 0.2608358851916014 w= [[1.13458208]
#  [0.66558896]
#  [0.21748621]] b= [0.32417425]
# step= 24800 error value= 0.2588160103207117 w= [[1.13519574]
#  [0.66562308]
#  [0.21683068]] b= [0.32415228]
# step= 25200 error value= 0.2568306365361038 w= [[1.13580525]
#  [0.66565485]
#  [0.21618172]] b= [0.32413024]
# step= 25600 error value= 0.2548791114101904 w= [[1.13641065]
#  [0.66568432]
#  [0.21553926]] b= [0.32410811]
# step= 26000 error value= 0.25296079644580083 w= [[1.13701194]
#  [0.66571153]
#  [0.21490322]] b= [0.32408591]
# step= 26400 error value= 0.25107506674191216 w= [[1.13760916]
#  [0.66573654]
#  [0.21427354]] b= [0.32406363]
# step= 26800 error value= 0.24922131066828584 w= [[1.13820234]
#  [0.6657594 ]
#  [0.21365015]] b= [0.32404127]
# step= 27200 error value= 0.24739892954842038 w= [[1.13879149]
#  [0.66578014]
#  [0.21303296]] b= [0.32401883]
# step= 27600 error value= 0.24560733735101 w= [[1.13937665]
#  [0.66579881]
#  [0.21242191]] b= [0.32399632]
# step= 28000 error value= 0.2438459603892475 w= [[1.13995783]
#  [0.66581545]
#  [0.21181694]] b= [0.32397373]
# step= 28400 error value= 0.24211423702823542 w= [[1.14053506]
#  [0.66583011]
#  [0.21121797]] b= [0.32395107]
# step= 28800 error value= 0.2404116173997281 w= [[1.14110837]
#  [0.66584284]
#  [0.21062493]] b= [0.32392833]
# step= 29200 error value= 0.23873756312448885 w= [[1.14167777]
#  [0.66585367]
#  [0.21003776]] b= [0.32390552]
# step= 29600 error value= 0.23709154704179042 w= [[1.1422433 ]
#  [0.66586264]
#  [0.2094564 ]] b= [0.32388264]
# step= 30000 error value= 0.23547305294586152 w= [[1.14280498]
#  [0.66586979]
#  [0.20888077]] b= [0.32385968]
# step= 30400 error value= 0.2338815753292362 w= [[1.14336282]
#  [0.66587517]
#  [0.20831082]] b= [0.32383666]
# step= 30800 error value= 0.2323166191326944 w= [[1.14391686]
#  [0.66587882]
#  [0.20774648]] b= [0.32381356]
# step= 31200 error value= 0.23077769950162325 w= [[1.14446712]
#  [0.66588076]
#  [0.20718769]] b= [0.32379039]
# step= 31600 error value= 0.22926434154868702 w= [[1.14501361]
#  [0.66588104]
#  [0.20663439]] b= [0.32376715]
# step= 32000 error value= 0.22777608012248557 w= [[1.14555637]
#  [0.6658797 ]
#  [0.20608651]] b= [0.32374384]
# step= 32400 error value= 0.2263124595823501 w= [[1.14609542]
#  [0.66587677]
#  [0.205544  ]] b= [0.32372046]
# step= 32800 error value= 0.22487303357863797 w= [[1.14663078]
#  [0.66587228]
#  [0.20500679]] b= [0.32369702]
# step= 33200 error value= 0.22345736483885564 w= [[1.14716248]
#  [0.66586628]
#  [0.20447483]] b= [0.3236735]
# step= 33600 error value= 0.22206502495911234 w= [[1.14769053]
#  [0.6658588 ]
#  [0.20394806]] b= [0.32364992]
# step= 34000 error value= 0.22069559420087043 w= [[1.14821496]
#  [0.66584986]
#  [0.20342642]] b= [0.32362627]
# step= 34400 error value= 0.21934866129298053 w= [[1.14873579]
#  [0.66583951]
#  [0.20290985]] b= [0.32360256]
# step= 34800 error value= 0.21802382323859099 w= [[1.14925305]
#  [0.66582778]
#  [0.20239831]] b= [0.32357878]
# step= 35200 error value= 0.2167206851269742 w= [[1.14976675]
#  [0.6658147 ]
#  [0.20189172]] b= [0.32355493]
# step= 35600 error value= 0.2154388599501585 w= [[1.15027693]
#  [0.6658003 ]
#  [0.20139005]] b= [0.32353102]
# step= 36000 error value= 0.21417796842418552 w= [[1.1507836 ]
#  [0.6657846 ]
#  [0.20089324]] b= [0.32350705]
# step= 36400 error value= 0.21293763881474495 w= [[1.15128678]
#  [0.66576765]
#  [0.20040122]] b= [0.32348301]
# step= 36800 error value= 0.21171750676729945 w= [[1.15178649]
#  [0.66574947]
#  [0.19991396]] b= [0.32345891]
# step= 37200 error value= 0.21051721514142047 w= [[1.15228277]
#  [0.6657301 ]
#  [0.19943139]] b= [0.32343475]
# step= 37600 error value= 0.20933641384927756 w= [[1.15277562]
#  [0.66570955]
#  [0.19895347]] b= [0.32341052]
# step= 38000 error value= 0.20817475969814841 w= [[1.15326508]
#  [0.66568786]
#  [0.19848015]] b= [0.32338623]
# step= 38400 error value= 0.20703191623682188 w= [[1.15375116]
#  [0.66566505]
#  [0.19801137]] b= [0.32336188]
# step= 38800 error value= 0.2059075536058971 w= [[1.15423388]
#  [0.66564116]
#  [0.19754709]] b= [0.32333747]
# step= 39200 error value= 0.20480134839165962 w= [[1.15471328]
#  [0.66561621]
#  [0.19708725]] b= [0.323313]
# step= 39600 error value= 0.20371298348372607 w= [[1.15518935]
#  [0.66559023]
#  [0.19663182]] b= [0.32328847]
# step= 40000 error value= 0.2026421479361185 w= [[1.15566214]
#  [0.66556324]
#  [0.19618074]] b= [0.32326388]
# step= 40400 error value= 0.2015885368316906 w= [[1.15613166]
#  [0.66553526]
#  [0.19573396]] b= [0.32323924]
# step= 40800 error value= 0.20055185115008864 w= [[1.15659793]
#  [0.66550633]
#  [0.19529144]] b= [0.32321453]
# step= 41200 error value= 0.19953179763870577 w= [[1.15706097]
#  [0.66547647]
#  [0.19485314]] b= [0.32318977]
# step= 41600 error value= 0.19852808868701896 w= [[1.1575208 ]
#  [0.66544569]
#  [0.194419  ]] b= [0.32316494]
# step= 42000 error value= 0.19754044220383776 w= [[1.15797744]
#  [0.66541404]
#  [0.19398898]] b= [0.32314007]
# step= 42400 error value= 0.19656858149758455 w= [[1.15843092]
#  [0.66538152]
#  [0.19356304]] b= [0.32311513]
# step= 42800 error value= 0.19561223515951193 w= [[1.15888125]
#  [0.66534816]
#  [0.19314114]] b= [0.32309014]
# step= 43200 error value= 0.19467113694977053 w= [[1.15932846]
#  [0.66531398]
#  [0.19272322]] b= [0.32306509]
# step= 43600 error value= 0.1937450256861998 w= [[1.15977256]
#  [0.66527901]
#  [0.19230926]] b= [0.32303999]
# step= 44000 error value= 0.1928336451357286 w= [[1.16021358]
#  [0.66524326]
#  [0.1918992 ]] b= [0.32301483]
# step= 44400 error value= 0.19193674390856927 w= [[1.16065153]
#  [0.66520677]
#  [0.19149301]] b= [0.32298962]
# step= 44800 error value= 0.19105407535481003 w= [[1.16108644]
#  [0.66516954]
#  [0.19109064]] b= [0.32296436]
# step= 45200 error value= 0.1901853974635175 w= [[1.16151832]
#  [0.6651316 ]
#  [0.19069205]] b= [0.32293904]
# step= 45600 error value= 0.18933047276430634 w= [[1.16194719]
#  [0.66509297]
#  [0.1902972 ]] b= [0.32291367]
# step= 46000 error value= 0.18848906823122588 w= [[1.16237308]
#  [0.66505367]
#  [0.18990606]] b= [0.32288824]
# step= 46400 error value= 0.1876609551888937 w= [[1.162796  ]
#  [0.66501372]
#  [0.18951858]] b= [0.32286277]
# step= 46800 error value= 0.18684590922089167 w= [[1.16321597]
#  [0.66497313]
#  [0.18913473]] b= [0.32283724]
# step= 47200 error value= 0.1860437100804377 w= [[1.16363302]
#  [0.66493193]
#  [0.18875446]] b= [0.32281166]
# step= 47600 error value= 0.18525414160296 w= [[1.16404715]
#  [0.66489013]
#  [0.18837775]] b= [0.32278603]
# step= 48000 error value= 0.18447699162085376 w= [[1.1644584 ]
#  [0.66484776]
#  [0.18800454]] b= [0.32276035]
# step= 48400 error value= 0.18371205188031695 w= [[1.16486677]
#  [0.66480482]
#  [0.18763481]] b= [0.32273462]
# step= 48800 error value= 0.18295911796000436 w= [[1.1652723 ]
#  [0.66476134]
#  [0.18726852]] b= [0.32270884]
# step= 49200 error value= 0.18221798919161278 w= [[1.16567499]
#  [0.66471734]
#  [0.18690562]] b= [0.32268301]
# step= 49600 error value= 0.181488468582414 w= [[1.16607486]
#  [0.66467282]
#  [0.1865461 ]] b= [0.32265713]
# step= 50000 error value= 0.1807703627394722 w= [[1.16647194]
#  [0.66462781]
#  [0.1861899 ]] b= [0.3226312]
# step= 50400 error value= 0.1800634817957246 w= [[1.16686624]
#  [0.66458232]
#  [0.18583701]] b= [0.32260522]
# step= 50800 error value= 0.1793676393376783 w= [[1.16725778]
#  [0.66453637]
#  [0.18548737]] b= [0.3225792]
# step= 51200 error value= 0.17868265233488986 w= [[1.16764658]
#  [0.66448997]
#  [0.18514096]] b= [0.32255313]
# step= 51600 error value= 0.17800834107096766 w= [[1.16803265]
#  [0.66444315]
#  [0.18479775]] b= [0.32252701]
# step= 52000 error value= 0.17734452907622986 w= [[1.16841602]
#  [0.6643959 ]
#  [0.18445769]] b= [0.32250084]
# step= 52400 error value= 0.17669104306191324 w= [[1.16879671]
#  [0.66434825]
#  [0.18412077]] b= [0.32247463]
# step= 52800 error value= 0.1760477128557854 w= [[1.16917472]
#  [0.66430021]
#  [0.18378694]] b= [0.32244837]
# step= 53200 error value= 0.17541437133943 w= [[1.16955008]
#  [0.6642518 ]
#  [0.18345617]] b= [0.32242207]
# step= 53600 error value= 0.1747908543867042 w= [[1.16992281]
#  [0.66420303]
#  [0.18312844]] b= [0.32239572]
# step= 54000 error value= 0.17417700080382933 w= [[1.17029292]
#  [0.66415391]
#  [0.18280371]] b= [0.32236933]
# step= 54400 error value= 0.1735726522706646 w= [[1.17066043]
#  [0.66410446]
#  [0.18248195]] b= [0.32234289]
# step= 54800 error value= 0.17297765328347622 w= [[1.17102536]
#  [0.66405469]
#  [0.18216312]] b= [0.3223164]
# step= 55200 error value= 0.17239185109877947 w= [[1.17138773]
#  [0.66400461]
#  [0.18184721]] b= [0.32228988]
# step= 55600 error value= 0.171815095678665 w= [[1.17174755]
#  [0.66395423]
#  [0.18153417]] b= [0.32226331]
# step= 56000 error value= 0.17124723963723334 w= [[1.17210483]
#  [0.66390356]
#  [0.18122399]] b= [0.32223669]
# step= 56400 error value= 0.17068813818824696 w= [[1.17245961]
#  [0.66385263]
#  [0.18091663]] b= [0.32221004]
# step= 56800 error value= 0.1701376490939058 w= [[1.17281188]
#  [0.66380144]
#  [0.18061205]] b= [0.32218334]
# step= 57200 error value= 0.16959563261491928 w= [[1.17316168]
#  [0.66374999]
#  [0.18031024]] b= [0.3221566]
# step= 57600 error value= 0.16906195146144315 w= [[1.17350901]
#  [0.66369831]
#  [0.18001117]] b= [0.32212981]
# step= 58000 error value= 0.1685364707453534 w= [[1.17385389]
#  [0.6636464 ]
#  [0.1797148 ]] b= [0.32210299]
# step= 58400 error value= 0.1680190579334035 w= [[1.17419635]
#  [0.66359428]
#  [0.17942111]] b= [0.32207612]
# step= 58800 error value= 0.16750958280148115 w= [[1.17453639]
#  [0.66354195]
#  [0.17913008]] b= [0.32204922]
# step= 59200 error value= 0.16700791738987233 w= [[1.17487403]
#  [0.66348943]
#  [0.17884167]] b= [0.32202227]
# step= 59600 error value= 0.16651393595941616 w= [[1.17520929]
#  [0.66343672]
#  [0.17855586]] b= [0.32199528]
# step= 60000 error value= 0.16602751494883697 w= [[1.17554219]
#  [0.66338383]
#  [0.17827262]] b= [0.32196826]
# step= 60400 error value= 0.16554853293270788 w= [[1.17587273]
#  [0.66333079]
#  [0.17799193]] b= [0.32194119]
# step= 60800 error value= 0.165076870580604 w= [[1.17620094]
#  [0.66327758]
#  [0.17771376]] b= [0.32191408]
# step= 61200 error value= 0.16461241061693271 w= [[1.17652683]
#  [0.66322423]
#  [0.17743809]] b= [0.32188694]
# step= 61600 error value= 0.16415503778177687 w= [[1.17685042]
#  [0.66317074]
#  [0.17716488]] b= [0.32185975]
# step= 62000 error value= 0.16370463879250438 w= [[1.17717172]
#  [0.66311713]
#  [0.17689412]] b= [0.32183253]
# step= 62400 error value= 0.16326110230619725 w= [[1.17749075]
#  [0.66306339]
#  [0.17662579]] b= [0.32180527]
# step= 62800 error value= 0.16282431888296778 w= [[1.17780752]
#  [0.66300955]
#  [0.17635985]] b= [0.32177797]
# step= 63200 error value= 0.16239418094995312 w= [[1.17812206]
#  [0.6629556 ]
#  [0.17609628]] b= [0.32175063]
# step= 63600 error value= 0.16197058276617277 w= [[1.17843436]
#  [0.66290156]
#  [0.17583506]] b= [0.32172326]
# step= 64000 error value= 0.16155342038806064 w= [[1.17874446]
#  [0.66284743]
#  [0.17557617]] b= [0.32169585]
# step= 64400 error value= 0.16114259163573136 w= [[1.17905236]
#  [0.66279322]
#  [0.17531958]] b= [0.3216684]
# step= 64800 error value= 0.1607379960600772 w= [[1.17935808]
#  [0.66273895]
#  [0.17506527]] b= [0.32164092]
# step= 65200 error value= 0.16033953491037317 w= [[1.17966163]
#  [0.66268461]
#  [0.17481321]] b= [0.3216134]
# step= 65600 error value= 0.1599471111027369 w= [[1.17996303]
#  [0.66263021]
#  [0.1745634 ]] b= [0.32158584]
# step= 66000 error value= 0.15956062918907196 w= [[1.18026229]
#  [0.66257577]
#  [0.17431579]] b= [0.32155825]
# step= 66400 error value= 0.15917999532691243 w= [[1.18055944]
#  [0.66252128]
#  [0.17407037]] b= [0.32153063]
# step= 66800 error value= 0.1588051172495497 w= [[1.18085447]
#  [0.66246676]
#  [0.17382713]] b= [0.32150296]
# step= 67200 error value= 0.158435904237199 w= [[1.18114741]
#  [0.66241222]
#  [0.17358603]] b= [0.32147527]
# step= 67600 error value= 0.15807226708835354 w= [[1.18143828]
#  [0.66235765]
#  [0.17334705]] b= [0.32144754]
# step= 68000 error value= 0.15771411809204544 w= [[1.18172707]
#  [0.66230307]
#  [0.17311019]] b= [0.32141977]
# step= 68400 error value= 0.15736137100048309 w= [[1.18201382]
#  [0.66224848]
#  [0.1728754 ]] b= [0.32139197]
# step= 68800 error value= 0.15701394100239607 w= [[1.18229853]
#  [0.66219389]
#  [0.17264268]] b= [0.32136414]
# step= 69200 error value= 0.15667174469674464 w= [[1.18258122]
#  [0.66213931]
#  [0.17241201]] b= [0.32133628]
# step= 69600 error value= 0.15633470006721445 w= [[1.1828619 ]
#  [0.66208473]
#  [0.17218336]] b= [0.32130838]
# step= 70000 error value= 0.15600272645698124 w= [[1.18314058]
#  [0.66203017]
#  [0.17195671]] b= [0.32128044]
# step= 70400 error value= 0.15567574454421032 w= [[1.18341728]
#  [0.66197563]
#  [0.17173205]] b= [0.32125248]
# step= 70800 error value= 0.15535367631781338 w= [[1.18369201]
#  [0.66192112]
#  [0.17150935]] b= [0.32122448]
# step= 71200 error value= 0.15503644505401587 w= [[1.18396479]
#  [0.66186665]
#  [0.1712886 ]] b= [0.32119645]
# step= 71600 error value= 0.15472397529300874 w= [[1.18423563]
#  [0.66181221]
#  [0.17106978]] b= [0.32116839]
# step= 72000 error value= 0.15441619281643235 w= [[1.18450454]
#  [0.66175781]
#  [0.17085286]] b= [0.3211403]
# step= 72400 error value= 0.15411302462510407 w= [[1.18477154]
#  [0.66170346]
#  [0.17063783]] b= [0.32111218]
# step= 72800 error value= 0.15381439891720866 w= [[1.18503663]
#  [0.66164917]
#  [0.17042468]] b= [0.32108402]
# step= 73200 error value= 0.15352024506703185 w= [[1.18529984]
#  [0.66159493]
#  [0.17021338]] b= [0.32105584]
# step= 73600 error value= 0.15323049360397187 w= [[1.18556117]
#  [0.66154076]
#  [0.17000391]] b= [0.32102762]
# step= 74000 error value= 0.15294507619210815 w= [[1.18582064]
#  [0.66148665]
#  [0.16979626]] b= [0.32099937]
# step= 74400 error value= 0.15266392561009773 w= [[1.18607826]
#  [0.66143262]
#  [0.16959041]] b= [0.3209711]
# step= 74800 error value= 0.15238697573142818 w= [[1.18633404]
#  [0.66137866]
#  [0.16938635]] b= [0.32094279]
# step= 75200 error value= 0.15211416150517043 w= [[1.186588  ]
#  [0.66132478]
#  [0.16918405]] b= [0.32091445]
# step= 75600 error value= 0.1518454189370436 w= [[1.18684015]
#  [0.66127098]
#  [0.1689835 ]] b= [0.32088609]
# step= 76000 error value= 0.15158068507085046 w= [[1.1870905 ]
#  [0.66121728]
#  [0.16878468]] b= [0.32085769]
# step= 76400 error value= 0.15131989797029294 w= [[1.18733906]
#  [0.66116367]
#  [0.16858757]] b= [0.32082926]
# step= 76800 error value= 0.15106299670113585 w= [[1.18758585]
#  [0.66111015]
#  [0.16839217]] b= [0.32080081]
# step= 77200 error value= 0.15080992131371246 w= [[1.18783087]
#  [0.66105674]
#  [0.16819845]] b= [0.32077233]
# step= 77600 error value= 0.15056061282579014 w= [[1.18807415]
#  [0.66100342]
#  [0.16800639]] b= [0.32074382]
# step= 78000 error value= 0.1503150132057693 w= [[1.18831569]
#  [0.66095022]
#  [0.16781599]] b= [0.32071528]
# step= 78400 error value= 0.1500730653561496 w= [[1.1885555 ]
#  [0.66089713]
#  [0.16762722]] b= [0.32068671]
# step= 78800 error value= 0.14983471309735555 w= [[1.1887936 ]
#  [0.66084415]
#  [0.16744007]] b= [0.32065812]
# step= 79200 error value= 0.1495999011519476 w= [[1.18903   ]
#  [0.66079129]
#  [0.16725452]] b= [0.3206295]
# step= 79600 error value= 0.14936857512896623 w= [[1.18926471]
#  [0.66073855]
#  [0.16707056]] b= [0.32060085]
# step= 80000 error value= 0.14914068150877263 w= [[1.18949774]
#  [0.66068593]
#  [0.16688818]] b= [0.32057217]
# step= 80400 error value= 0.1489161676279593 w= [[1.1897291 ]
#  [0.66063344]
#  [0.16670736]] b= [0.32054347]
# step= 80800 error value= 0.14869498166479606 w= [[1.18995881]
#  [0.66058108]
#  [0.16652807]] b= [0.32051474]
# step= 81200 error value= 0.14847707262473336 w= [[1.19018688]
#  [0.66052886]
#  [0.16635032]] b= [0.32048598]
# step= 81600 error value= 0.14826239032624536 w= [[1.19041331]
#  [0.66047677]
#  [0.16617409]] b= [0.3204572]
# step= 82000 error value= 0.14805088538711458 w= [[1.19063813]
#  [0.66042482]
#  [0.16599935]] b= [0.32042839]
# step= 82400 error value= 0.1478425092106276 w= [[1.19086133]
#  [0.66037301]
#  [0.1658261 ]] b= [0.32039956]
# step= 82800 error value= 0.14763721397237278 w= [[1.19108294]
#  [0.66032134]
#  [0.16565433]] b= [0.32037069]
# step= 83200 error value= 0.14743495260710998 w= [[1.19130296]
#  [0.66026982]
#  [0.16548401]] b= [0.32034181]
# step= 83600 error value= 0.14723567879584404 w= [[1.1915214 ]
#  [0.66021845]
#  [0.16531514]] b= [0.3203129]
# step= 84000 error value= 0.14703934695331583 w= [[1.19173828]
#  [0.66016723]
#  [0.1651477 ]] b= [0.32028396]
# step= 84400 error value= 0.14684591221550783 w= [[1.19195361]
#  [0.66011616]
#  [0.16498168]] b= [0.320255]
# step= 84800 error value= 0.14665533042762763 w= [[1.19216739]
#  [0.66006525]
#  [0.16481707]] b= [0.32022602]
# step= 85200 error value= 0.1464675581320572 w= [[1.19237964]
#  [0.6600145 ]
#  [0.16465384]] b= [0.32019701]
# step= 85600 error value= 0.1462825525567414 w= [[1.19259036]
#  [0.6599639 ]
#  [0.164492  ]] b= [0.32016797]
# step= 86000 error value= 0.1461002716036371 w= [[1.19279958]
#  [0.65991347]
#  [0.16433152]] b= [0.32013891]
# step= 86400 error value= 0.14592067383745463 w= [[1.1930073 ]
#  [0.65986321]
#  [0.16417239]] b= [0.32010983]
# step= 86800 error value= 0.14574371847461778 w= [[1.19321352]
#  [0.6598131 ]
#  [0.16401461]] b= [0.32008072]
# step= 87200 error value= 0.14556936537233373 w= [[1.19341827]
#  [0.65976317]
#  [0.16385816]] b= [0.32005159]
# step= 87600 error value= 0.14539757501797893 w= [[1.19362155]
#  [0.6597134 ]
#  [0.16370302]] b= [0.32002244]
# step= 88000 error value= 0.14522830851862106 w= [[1.19382337]
#  [0.65966381]
#  [0.16354918]] b= [0.31999326]
# step= 88400 error value= 0.14506152759067376 w= [[1.19402374]
#  [0.65961439]
#  [0.16339664]] b= [0.31996406]
# step= 88800 error value= 0.14489719454987676 w= [[1.19422267]
#  [0.65956514]
#  [0.16324538]] b= [0.31993484]
# step= 89200 error value= 0.14473527230129407 w= [[1.19442018]
#  [0.65951607]
#  [0.16309538]] b= [0.3199056]
# step= 89600 error value= 0.14457572432970714 w= [[1.19461626]
#  [0.65946718]
#  [0.16294665]] b= [0.31987633]
# step= 90000 error value= 0.14441851468986266 w= [[1.19481094]
#  [0.65941847]
#  [0.16279915]] b= [0.31984704]
# step= 90400 error value= 0.1442636079973214 w= [[1.19500422]
#  [0.65936993]
#  [0.1626529 ]] b= [0.31981773]
# step= 90800 error value= 0.14411096941900406 w= [[1.19519611]
#  [0.65932158]
#  [0.16250786]] b= [0.31978839]
# step= 91200 error value= 0.1439605646642769 w= [[1.19538662]
#  [0.65927342]
#  [0.16236403]] b= [0.31975904]
# step= 91600 error value= 0.14381235997603822 w= [[1.19557576]
#  [0.65922543]
#  [0.16222141]] b= [0.31972966]
# step= 92000 error value= 0.14366632212191768 w= [[1.19576354]
#  [0.65917763]
#  [0.16207997]] b= [0.31970026]
# step= 92400 error value= 0.14352241838577667 w= [[1.19594998]
#  [0.65913002]
#  [0.16193972]] b= [0.31967084]
# step= 92800 error value= 0.14338061655924114 w= [[1.19613507]
#  [0.6590826 ]
#  [0.16180063]] b= [0.3196414]
# step= 93200 error value= 0.14324088493339424 w= [[1.19631883]
#  [0.65903536]
#  [0.16166269]] b= [0.31961193]
# step= 93600 error value= 0.14310319229071536 w= [[1.19650127]
#  [0.65898832]
#  [0.16152591]] b= [0.31958245]
# step= 94000 error value= 0.14296750789699755 w= [[1.1966824 ]
#  [0.65894146]
#  [0.16139025]] b= [0.31955295]
# step= 94400 error value= 0.14283380149360517 w= [[1.19686222]
#  [0.6588948 ]
#  [0.16125573]] b= [0.31952342]
# step= 94800 error value= 0.1427020432896569 w= [[1.19704075]
#  [0.65884833]
#  [0.16112232]] b= [0.31949388]
# step= 95200 error value= 0.1425722039545441 w= [[1.19721799]
#  [0.65880205]
#  [0.16099002]] b= [0.31946431]
# step= 95600 error value= 0.14244425461037877 w= [[1.19739396]
#  [0.65875597]
#  [0.16085881]] b= [0.31943473]
# step= 96000 error value= 0.1423181668248013 w= [[1.19756867]
#  [0.65871008]
#  [0.16072868]] b= [0.31940512]
# step= 96400 error value= 0.14219391260368858 w= [[1.19774211]
#  [0.65866439]
#  [0.16059963]] b= [0.3193755]
# step= 96800 error value= 0.1420714643841549 w= [[1.19791431]
#  [0.65861889]
#  [0.16047165]] b= [0.31934585]
# step= 97200 error value= 0.14195079502760813 w= [[1.19808526]
#  [0.6585736 ]
#  [0.16034473]] b= [0.31931619]
# step= 97600 error value= 0.14183187781287573 w= [[1.19825499]
#  [0.6585285 ]
#  [0.16021885]] b= [0.3192865]
# step= 98000 error value= 0.1417146864295834 w= [[1.19842349]
#  [0.65848359]
#  [0.16009401]] b= [0.3192568]
# step= 98400 error value= 0.14159919497150067 w= [[1.19859078]
#  [0.65843889]
#  [0.15997019]] b= [0.31922708]
# step= 98800 error value= 0.14148537793011684 w= [[1.19875686]
#  [0.65839439]
#  [0.1598474 ]] b= [0.31919734]
# step= 99200 error value= 0.14137321018821697 w= [[1.19892175]
#  [0.65835008]
#  [0.15972561]] b= [0.31916758]
# step= 99600 error value= 0.14126266701372125 w= [[1.19908545]
#  [0.65830598]
#  [0.15960483]] b= [0.3191378]
