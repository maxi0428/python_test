# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib import rc, font_manager
font_path='c:/Windows/Fonts/gulim.ttc'
font_name=font_manager.FontProperties(fname=font_path).get_name()
rc('font',family=font_name)

plt.rcParams['figure.figsize']=(10,9)
plt.rcParams['axes.unicode_minus']=False

# %%
sns.set(style='darkgrid')

# %% [markdown]
# # Pairplot, Implot, jointplot

# %%
tips=sns.load_dataset('tips')

# %% [markdown]
# # Pairplot
# - 그리드 형태로 각 집합의 조합에 대해 히스토 그램과 분포도를 표시
# - 숫자형 columns에 대해서만 차트 작성

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips,hue='size')

# %% [markdown]
# # Lmplot
# - column 간의 선형관계를 확인하기에 용이한 차트

# %%
sns.lmplot(x='total_bill',y='tip', data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, hue='smoker')

# %%
sns.lmplot(x='total_bill',y='tip', data=tips, hue='smoker', col='day', col_wrap=3)

# %% [markdown]
# # jointplot
# - scotter(산점도)와 histogram(분포)을 동시에 그려주며 숫자형 데이터만 표현가능

# %%
sns.jointplot(x='total_bill',y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill',y='tip', data=tips, hue='smoker')

# %%
taxi = sns.load_dataset('taxis')

# %%
sns.pairplot(taxi)

# %%
sns.lmplot(x='total',y='tip', data=taxi, hue='fare')

# %%
sns.jointplot(x='total',y='tip', data=taxi, kind='reg')
